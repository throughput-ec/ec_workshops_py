# %% [markdown]
# # process taxa names

# %%
import pandas as pd
from datetime import date
from pathlib import Path 
import numpy as np
import time
import requests

import sys
sys.path.append(str(Path.cwd().parent))

from scripts.normalize_taxa import (
    taxon_name_parser, 
    get_parent_taxa, 
    PBDB_TAXA_NAME,
    add_normalized_name_column
)
from scripts.normalize_data import print_df

# %%
taxa_draft_path = Path('..', 'processed_data', 'drafts', 'taxa_list.csv')
genus_path = Path('..', 'processed_data', 'drafts', 'genera.csv')

approved_taxa_path = Path('..', 'raw_data', 'PI_processed_files', 'LIMS_Micropal_headers_PBDB_Taxonomy_notes_taxa_list_2022-02-22.csv')
taxa_search_path = Path('..', 'processed_data', 'draft', 'taxa_list_search.csv')

# %% [markdown]
# ## add name parts columns to taxa file

# %%
taxa_list_df = pd.read_csv(taxa_draft_path)
taxa_list_df.head()
# Out:
#                           verbatim_name
# 0                       Beella digitata
# 1                       Candeina nitida
# 2            Dentoglobigerina altispira
# 3   Dentoglobigerina altispira _T_ _PL5
# 4  Dentoglobigerina altispira _T_ _PL5_

# %%
taxa_list = []

for taxon in taxa_list_df['verbatim_name'].values:
    if not pd.isna(taxon):
        
        taxon_name_parts = taxon_name_parser(taxon)
        taxon_name_parts['verbatim_name'] = taxon
 
        taxa_list.append(taxon_name_parts)
        
len(taxa_list)
# Out:
# 141

# %%
new_df = pd.DataFrame(taxa_list)
print_df(new_df)
# Out:
# (141, 7)
#          genus name species name                         verbatim_name  \
# 0            Beella     digitata                       Beella digitata
# 1          Candeina       nitida                       Candeina nitida
# 2  Dentoglobigerina    altispira            Dentoglobigerina altispira
# 3  Dentoglobigerina    altispira   Dentoglobigerina altispira _T_ _PL5
# 4  Dentoglobigerina    altispira  Dentoglobigerina altispira _T_ _PL5_
#
#   subspecies name species modifier non-taxa descriptor subspecies modifier
# 0             NaN              NaN                 NaN                 NaN
# 1             NaN              NaN                 NaN                 NaN
# 2             NaN              NaN                 NaN                 NaN
# 3             _T_              NaN                 NaN                 NaN
# 4             _T_              NaN                 NaN                 NaN

# %%
new_df.to_csv(taxa_draft_path, index=False)

# %% [markdown]
# ## add pbdb taxon ids for genera

# %%
taxa_df = pd.read_csv(taxa_draft_path, dtype=str)
print_df(taxa_df)
# Out:
# (141, 7)
#          genus name species name                         verbatim_name  \
# 0            Beella     digitata                       Beella digitata
# 1          Candeina       nitida                       Candeina nitida
# 2  Dentoglobigerina    altispira            Dentoglobigerina altispira
# 3  Dentoglobigerina    altispira   Dentoglobigerina altispira _T_ _PL5
# 4  Dentoglobigerina    altispira  Dentoglobigerina altispira _T_ _PL5_
#
#   subspecies name species modifier non-taxa descriptor subspecies modifier
# 0             NaN              NaN                 NaN                 NaN
# 1             NaN              NaN                 NaN                 NaN
# 2             NaN              NaN                 NaN                 NaN
# 3             _T_              NaN                 NaN                 NaN
# 4             _T_              NaN                 NaN                 NaN

# %%
genus_df = pd.DataFrame(taxa_df['genus name'].unique(), columns=['genus name'])

print_df(genus_df)
# Out:
# (18, 1)
#           genus name
# 0             Beella
# 1           Candeina
# 2   Dentoglobigerina
# 3  Dextral:Sinistral
# 4        Globigerina

# %%
for index, row in genus_df.iterrows():

    time.sleep(0.25)
    
    if index % 50 == 0:
        print(index, end=' ')

        
    url =  PBDB_TAXA_NAME +  row['genus name']
        
    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()["records"]
        if len(data) == 1:
            genus_df.at[index, f'pbdb_taxon_id'] = str(data[0]["taxon_no"])
            genus_df.at[index, f'pbdb_taxon_name'] = data[0]["taxon_name"]
            genus_df.at[index, f'pbdb_taxon_rank'] = data[0]["taxon_rank"]
            
            round = 0
            get_parent_taxa(genus_df, data[0]["parent_no"], data[0]["taxon_rank"], round, index, None)
# Out:
# 0

# %%
print_df(genus_df)
# Out:
# (18, 10)
#           genus name pbdb_taxon_id   pbdb_taxon_name pbdb_taxon_rank  \
# 0             Beella           951            Beella           genus
# 1           Candeina          1053          Candeina           genus
# 2   Dentoglobigerina          1264  Dentoglobigerina           genus
# 3  Dextral:Sinistral           NaN               NaN             NaN
# 4        Globigerina          1498       Globigerina           genus
#
#   family_taxon_id family_taxon_name phylum_taxon_id phylum_taxon_name  \
# 0           82191    Globigerinidae          288974      Foraminifera
# 1          422277       Candeinidae          288974      Foraminifera
# 2           82191    Globigerinidae          288974      Foraminifera
# 3             NaN               NaN             NaN               NaN
# 4           82191    Globigerinidae          288974      Foraminifera
#
#   kingdom_taxon_id kingdom_taxon_name
# 0           212476           Rhizaria
# 1           212476           Rhizaria
# 2           212476           Rhizaria
# 3              NaN                NaN
# 4           212476           Rhizaria

# %%
genus_df.to_csv(genus_path, index=False)

# %%
merged_df = taxa_df.merge(genus_df,  on = 'genus name' )

print_df(merged_df)
# Out:
# (141, 16)
#          genus name species name                         verbatim_name  \
# 0            Beella     digitata                       Beella digitata
# 1          Candeina       nitida                       Candeina nitida
# 2  Dentoglobigerina    altispira            Dentoglobigerina altispira
# 3  Dentoglobigerina    altispira   Dentoglobigerina altispira _T_ _PL5
# 4  Dentoglobigerina    altispira  Dentoglobigerina altispira _T_ _PL5_
#
#   subspecies name species modifier non-taxa descriptor subspecies modifier  \
# 0             NaN              NaN                 NaN                 NaN
# 1             NaN              NaN                 NaN                 NaN
# 2             NaN              NaN                 NaN                 NaN
# 3             _T_              NaN                 NaN                 NaN
# 4             _T_              NaN                 NaN                 NaN
#
#   pbdb_taxon_id   pbdb_taxon_name pbdb_taxon_rank family_taxon_id  \
# 0           951            Beella           genus           82191
# 1          1053          Candeina           genus          422277
# 2          1264  Dentoglobigerina           genus           82191
# 3          1264  Dentoglobigerina           genus           82191
# 4          1264  Dentoglobigerina           genus           82191
#
#   family_taxon_name phylum_taxon_id phylum_taxon_name kingdom_taxon_id  \
# 0    Globigerinidae          288974      Foraminifera           212476
# 1       Candeinidae          288974      Foraminifera           212476
# 2    Globigerinidae          288974      Foraminifera           212476
# 3    Globigerinidae          288974      Foraminifera           212476
# 4    Globigerinidae          288974      Foraminifera           212476
#
#   kingdom_taxon_name
# 0           Rhizaria
# 1           Rhizaria
# 2           Rhizaria
# 3           Rhizaria
# 4           Rhizaria

# %%
merged_df.to_csv(taxa_draft_path, index=False)

# %% [markdown]
# ## create csv to search for taxa

# %%
all_taxa_df = pd.read_csv(approved_taxa_path, dtype=str)

print_df(all_taxa_df, 2)
# Out:
# (4753, 32)
#       taxon_group                      verbatim_name  \
# 0  benthic_forams                             Pyrite
# 1  benthic_forams  Euuvigerina miozea (group) >100 m
#
#                                 name name to use (if different from "name")  \
# 0                             Pyrite                                    NaN
# 1  Euuvigerina miozea (group) >100 m                     Euuvigerina miozea
#
#   name comment field                                      Comment  \
# 0                NaN  not a taxa; Going into Macrostrat, not PBDB
# 1                NaN                                        group
#
#                                                notes Any taxon above genus  \
# 0  Summer 2020: deal with later; should go in as ...                   NaN
# 1  Summer 2020: enter "Euuvigerina miozea" and re...                   NaN
#
#   genus modifier   genus name  ... family_taxon_id family_taxon_name  \
# 0            NaN          NaN  ...             NaN               NaN
# 1            NaN  Euuvigerina  ...             NaN               NaN
#
#   order_taxon_id order_taxon_name class_taxon_id class_taxon_name  \
# 0            NaN              NaN            NaN              NaN
# 1            NaN              NaN            NaN              NaN
#
#   phylum_taxon_id phylum_taxon_name kingdom_taxon_id kingdom_taxon_name
# 0             NaN               NaN              NaN                NaN
# 1          288974      Foraminifera           212476           Rhizaria
#
# [2 rows x 32 columns]

# %%
del all_taxa_df['taxon_group']
del all_taxa_df['notes']
del all_taxa_df['name comment field']
del all_taxa_df['Comment']


all_taxa_df.drop_duplicates(inplace=True)
print_df(all_taxa_df, 2)
# Out:
# (4606, 28)
#                        verbatim_name                               name  \
# 0                             Pyrite                             Pyrite
# 1  Euuvigerina miozea (group) >100 m  Euuvigerina miozea (group) >100 m
#
#   name to use (if different from "name") Any taxon above genus genus modifier  \
# 0                                    NaN                   NaN            NaN
# 1                     Euuvigerina miozea                   NaN            NaN
#
#     genus name subgenera modifier subgenera name species modifier  \
# 0          NaN                NaN            NaN              NaN
# 1  Euuvigerina                NaN            NaN              NaN
#
#   species name  ... family_taxon_id family_taxon_name order_taxon_id  \
# 0          NaN  ...             NaN               NaN            NaN
# 1       miozea  ...             NaN               NaN            NaN
#
#   order_taxon_name class_taxon_id class_taxon_name phylum_taxon_id  \
# 0              NaN            NaN              NaN             NaN
# 1              NaN            NaN              NaN          288974
#
#   phylum_taxon_name kingdom_taxon_id kingdom_taxon_name
# 0               NaN              NaN                NaN
# 1      Foraminifera           212476           Rhizaria
#
# [2 rows x 28 columns]

# %%
taxa_df = pd.read_csv(taxa_draft_path, dtype=str, usecols=['verbatim_name'])

# %%
merged_df = taxa_df.merge(all_taxa_df)
print_df(merged_df)
# Out:
# (144, 28)
#                           verbatim_name                                  name  \
# 0                       Beella digitata                       Beella digitata
# 1                       Candeina nitida                       Candeina nitida
# 2            Dentoglobigerina altispira            Dentoglobigerina altispira
# 3   Dentoglobigerina altispira _T_ _PL5   Dentoglobigerina altispira _T_ _PL5
# 4  Dentoglobigerina altispira _T_ _PL5_  Dentoglobigerina altispira _T_ _PL5_
#
#   name to use (if different from "name") Any taxon above genus genus modifier  \
# 0                                    NaN                   NaN            NaN
# 1                                    NaN                   NaN            NaN
# 2                                    NaN                   NaN            NaN
# 3             Dentoglobigerina altispira                   NaN            NaN
# 4             Dentoglobigerina altispira                   NaN            NaN
#
#           genus name subgenera modifier subgenera name species modifier  \
# 0             Beella                NaN            NaN              NaN
# 1           Candeina                NaN            NaN              NaN
# 2   Dentoglobigerina                NaN            NaN              NaN
# 3  Dentoglobigerina                 NaN            NaN              NaN
# 4  Dentoglobigerina                 NaN            NaN              NaN
#
#   species name  ... family_taxon_id family_taxon_name order_taxon_id  \
# 0     digitata  ...           82191    Globigerinidae            NaN
# 1       nitida  ...          422277       Candeinidae            NaN
# 2    altispira  ...           82191    Globigerinidae            NaN
# 3    altispira  ...           82191    Globigerinidae            NaN
# 4    altispira  ...           82191    Globigerinidae            NaN
#
#   order_taxon_name class_taxon_id class_taxon_name phylum_taxon_id  \
# 0              NaN            NaN              NaN          288974
# 1              NaN            NaN              NaN          288974
# 2              NaN            NaN              NaN          288974
# 3              NaN            NaN              NaN          288974
# 4              NaN            NaN              NaN          288974
#
#   phylum_taxon_name kingdom_taxon_id kingdom_taxon_name
# 0      Foraminifera           212476           Rhizaria
# 1      Foraminifera           212476           Rhizaria
# 2      Foraminifera           212476           Rhizaria
# 3      Foraminifera           212476           Rhizaria
# 4      Foraminifera           212476           Rhizaria
#
# [5 rows x 28 columns]

# %%
add_normalized_name_column(merged_df)
add_normalized_name_column(merged_df, include_descriptor=False, 
                           include_modifier=False, col_name='basic_name')

print_df(merged_df)
# Out:
# (144, 30)
#                           verbatim_name                                  name  \
# 0                       Beella digitata                       Beella digitata
# 1                       Candeina nitida                       Candeina nitida
# 2            Dentoglobigerina altispira            Dentoglobigerina altispira
# 3   Dentoglobigerina altispira _T_ _PL5   Dentoglobigerina altispira _T_ _PL5
# 4  Dentoglobigerina altispira _T_ _PL5_  Dentoglobigerina altispira _T_ _PL5_
#
#   name to use (if different from "name") Any taxon above genus genus modifier  \
# 0                                    NaN                   NaN            NaN
# 1                                    NaN                   NaN            NaN
# 2                                    NaN                   NaN            NaN
# 3             Dentoglobigerina altispira                   NaN            NaN
# 4             Dentoglobigerina altispira                   NaN            NaN
#
#           genus name subgenera modifier subgenera name species modifier  \
# 0             Beella                NaN            NaN              NaN
# 1           Candeina                NaN            NaN              NaN
# 2   Dentoglobigerina                NaN            NaN              NaN
# 3  Dentoglobigerina                 NaN            NaN              NaN
# 4  Dentoglobigerina                 NaN            NaN              NaN
#
#   species name  ... order_taxon_id order_taxon_name class_taxon_id  \
# 0     digitata  ...            NaN              NaN            NaN
# 1       nitida  ...            NaN              NaN            NaN
# 2    altispira  ...            NaN              NaN            NaN
# 3    altispira  ...            NaN              NaN            NaN
# 4    altispira  ...            NaN              NaN            NaN
#
#   class_taxon_name phylum_taxon_id phylum_taxon_name kingdom_taxon_id  \
# 0              NaN          288974      Foraminifera           212476
# 1              NaN          288974      Foraminifera           212476
# 2              NaN          288974      Foraminifera           212476
# 3              NaN          288974      Foraminifera           212476
# 4              NaN          288974      Foraminifera           212476
#
#   kingdom_taxon_name             normalized_name                  basic_name
# 0           Rhizaria             Beella digitata             Beella digitata
# 1           Rhizaria             Candeina nitida             Candeina nitida
# 2           Rhizaria  Dentoglobigerina altispira  Dentoglobigerina altispira
# 3           Rhizaria  Dentoglobigerina altispira  Dentoglobigerina altispira
# 4           Rhizaria  Dentoglobigerina altispira  Dentoglobigerina altispira
#
# [5 rows x 30 columns]

# %%
taxa_df = merged_df[['verbatim_name', 'normalized_name', 'basic_name']]
taxa_df
# Out:
#                                 verbatim_name  \
# 0                             Beella digitata
# 1                             Candeina nitida
# 2                  Dentoglobigerina altispira
# 3         Dentoglobigerina altispira _T_ _PL5
# 4        Dentoglobigerina altispira _T_ _PL5_
# ..                                        ...
# 139   Sphaeroidinellopsis seminulina _T_ _PL4
# 140  Sphaeroidinellopsis seminulina _T_ _PL4_
# 141          Sphaeroidinellopsis subdehiscens
# 142                     Turborotalita humilis
# 143                 Turborotalita quinqueloba
#
#                       normalized_name                        basic_name
# 0                     Beella digitata                   Beella digitata
# 1                     Candeina nitida                   Candeina nitida
# 2          Dentoglobigerina altispira        Dentoglobigerina altispira
# 3          Dentoglobigerina altispira        Dentoglobigerina altispira
# 4          Dentoglobigerina altispira        Dentoglobigerina altispira
# ..                                ...                               ...
# 139    Sphaeroidinellopsis seminulina    Sphaeroidinellopsis seminulina
# 140    Sphaeroidinellopsis seminulina    Sphaeroidinellopsis seminulina
# 141  Sphaeroidinellopsis subdehiscens  Sphaeroidinellopsis subdehiscens
# 142             Turborotalita humilis             Turborotalita humilis
# 143         Turborotalita quinqueloba         Turborotalita quinqueloba
#
# [144 rows x 3 columns]

# %%
taxa_df.to_csv(taxa_search_path, index=False)
