# %%
import pandas as pd
from datetime import date
from pathlib import Path 
import re

import sys
sys.path.append(str(Path.cwd().parent))

from scripts.normalize_data import (
    ddm2dec,
    print_df
)

from scripts.normalize_taxa import (
    add_normalized_name_column
)

# %%
hole_path = Path('..', 'processed_data', 'Hole Summary_23_2_2021.csv')
approved_taxa_path = Path('..', 'raw_data', 'PI_processed_files', 'LIMS_Micropal_headers_PBDB_Taxonomy_notes_taxa_list_2022-02-22.csv')
taxa_draft_path = Path('..', 'processed_data', 'drafts', 'taxa_list.csv')
noramalized_taxa_path = Path('..', 'processed_data',  'normalized_taxa_list.csv')

# %% [markdown]
# # clean up holes coordinates

# %%
na_values = ['', '*']             
hole_df = pd.read_csv(hole_path, na_values=na_values)
print_df(hole_df)
# Out:
# (3821, 22)
#   Exp Site Hole     Latitude     Longitude  Water depth (m)  \
# 0   1    1  NaN  25 51.498 N   92 10.998 W              NaN
# 1   1    2  NaN    23 27.3 N  92 35.2002 W              NaN
# 2   1    3  NaN     23 1.8 N    92 2.598 W              NaN
# 3   1    4  NaN   24 28.68 N    73 47.52 W              NaN
# 4   1    4    A   24 28.68 N    73 47.52 W              NaN
#
#    Penetration DSF (m)  Cored interval (m)  Recovered length (m)  \
# 0                 86.3                77.2                  58.7
# 1                 26.5                26.5                  12.1
# 2                 99.2                99.2                  46.6
# 3                 36.7                36.7                  12.9
# 4                 18.2                18.2                   5.7
#
#    Recovery (%)  ...  Total cores (no.)  APC cores (no.)  HLAPC cores (no.)  \
# 0         76.04  ...                  9                0                  0
# 1         45.66  ...                  5                0                  0
# 2         46.98  ...                 11                0                  0
# 3         35.15  ...                  4                0                  0
# 4         31.32  ...                  2                0                  0
#
#    XCB cores (no.)  RCB cores (no.)  Other cores (no.)  Date started (UTC)  \
# 0                0                8                  1    10/23/1997 08:44
# 1                0                5                  0    10/23/1997 08:45
# 2                0               11                  0    10/23/1997 08:45
# 3                0                4                  0    10/23/1997 08:45
# 4                0                2                  0    10/23/1997 08:45
#
#    Date finished (UTC) Time on hole (days) Comments
# 0     10/23/1997 08:44                 0.0      NaN
# 1     10/23/1997 08:45                 0.0      NaN
# 2     10/23/1997 08:45                 0.0      NaN
# 3     10/23/1997 08:45                 0.0      NaN
# 4     10/23/1997 08:45                 0.0      NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# remove bad rows

# %%
hole_df = hole_df[hole_df['Exp'] != 'TEST']
hole_df = hole_df[hole_df['Exp'] != '999']
hole_df.dropna(axis='index', how='all',  inplace=True, subset=['Latitude', 'Longitude'])

# %% [markdown]
# fix typos

# %%
hole_df.loc[2935, 'Latitude'] = '38 49.7822 S'
hole_df.loc[2964, 'Latitude'] = '38 8.1532 S'

# %% [markdown]
# add decimal coordinates

# %%
hole_df['Latitude_decimal'] = hole_df['Latitude'].apply(ddm2dec)
hole_df['Longitude_decimal'] = hole_df['Longitude'].apply(ddm2dec)

# %%
print_df(hole_df)
# Out:
# (3789, 24)
#   Exp Site Hole     Latitude     Longitude  Water depth (m)  \
# 0   1    1  NaN  25 51.498 N   92 10.998 W              NaN
# 1   1    2  NaN    23 27.3 N  92 35.2002 W              NaN
# 2   1    3  NaN     23 1.8 N    92 2.598 W              NaN
# 3   1    4  NaN   24 28.68 N    73 47.52 W              NaN
# 4   1    4    A   24 28.68 N    73 47.52 W              NaN
#
#    Penetration DSF (m)  Cored interval (m)  Recovered length (m)  \
# 0                 86.3                77.2                  58.7
# 1                 26.5                26.5                  12.1
# 2                 99.2                99.2                  46.6
# 3                 36.7                36.7                  12.9
# 4                 18.2                18.2                   5.7
#
#    Recovery (%)  ...  HLAPC cores (no.)  XCB cores (no.)  RCB cores (no.)  \
# 0         76.04  ...                  0                0                8
# 1         45.66  ...                  0                0                5
# 2         46.98  ...                  0                0               11
# 3         35.15  ...                  0                0                4
# 4         31.32  ...                  0                0                2
#
#    Other cores (no.)  Date started (UTC)  Date finished (UTC)  \
# 0                  1    10/23/1997 08:44     10/23/1997 08:44
# 1                  0    10/23/1997 08:45     10/23/1997 08:45
# 2                  0    10/23/1997 08:45     10/23/1997 08:45
# 3                  0    10/23/1997 08:45     10/23/1997 08:45
# 4                  0    10/23/1997 08:45     10/23/1997 08:45
#
#    Time on hole (days)  Comments Latitude_decimal Longitude_decimal
# 0                  0.0       NaN          25.8583         -92.18330
# 1                  0.0       NaN          23.4550         -92.58667
# 2                  0.0       NaN          23.0300         -92.04330
# 3                  0.0       NaN          24.4780         -73.79200
# 4                  0.0       NaN          24.4780         -73.79200
#
# [5 rows x 24 columns]

# %%
hole_df.to_csv(hole_path, index=False)

# %% [markdown]
# ## create normalize taxa

# %%
all_taxa_df = pd.read_csv(approved_taxa_path, dtype=str)

print_df(all_taxa_df, 2)
# Out:
# (4753, 32)
#       taxon_group                      verbatim_name  \
# 0  benthic_forams                             Pyrite
# 1  benthic_forams  Euuvigerina miozea (group) >100 m
#
#                                 name name to use (if different from "name")  \
# 0                             Pyrite                                    NaN
# 1  Euuvigerina miozea (group) >100 m                     Euuvigerina miozea
#
#   name comment field                                      Comment  \
# 0                NaN  not a taxa; Going into Macrostrat, not PBDB
# 1                NaN                                        group
#
#                                                notes Any taxon above genus  \
# 0  Summer 2020: deal with later; should go in as ...                   NaN
# 1  Summer 2020: enter "Euuvigerina miozea" and re...                   NaN
#
#   genus modifier   genus name  ... family_taxon_id family_taxon_name  \
# 0            NaN          NaN  ...             NaN               NaN
# 1            NaN  Euuvigerina  ...             NaN               NaN
#
#   order_taxon_id order_taxon_name class_taxon_id class_taxon_name  \
# 0            NaN              NaN            NaN              NaN
# 1            NaN              NaN            NaN              NaN
#
#   phylum_taxon_id phylum_taxon_name kingdom_taxon_id kingdom_taxon_name
# 0             NaN               NaN              NaN                NaN
# 1          288974      Foraminifera           212476           Rhizaria
#
# [2 rows x 32 columns]

# %%
del all_taxa_df['taxon_group']
del all_taxa_df['notes']
del all_taxa_df['name comment field']
del all_taxa_df['Comment']


all_taxa_df.drop_duplicates(inplace=True)
print_df(all_taxa_df, 2)
# Out:
# (4606, 28)
#                        verbatim_name                               name  \
# 0                             Pyrite                             Pyrite
# 1  Euuvigerina miozea (group) >100 m  Euuvigerina miozea (group) >100 m
#
#   name to use (if different from "name") Any taxon above genus genus modifier  \
# 0                                    NaN                   NaN            NaN
# 1                     Euuvigerina miozea                   NaN            NaN
#
#     genus name subgenera modifier subgenera name species modifier  \
# 0          NaN                NaN            NaN              NaN
# 1  Euuvigerina                NaN            NaN              NaN
#
#   species name  ... family_taxon_id family_taxon_name order_taxon_id  \
# 0          NaN  ...             NaN               NaN            NaN
# 1       miozea  ...             NaN               NaN            NaN
#
#   order_taxon_name class_taxon_id class_taxon_name phylum_taxon_id  \
# 0              NaN            NaN              NaN             NaN
# 1              NaN            NaN              NaN          288974
#
#   phylum_taxon_name kingdom_taxon_id kingdom_taxon_name
# 0               NaN              NaN                NaN
# 1      Foraminifera           212476           Rhizaria
#
# [2 rows x 28 columns]

# %%
taxa_df = pd.read_csv(taxa_draft_path, dtype=str, usecols=['verbatim_name'])
print_df(taxa_df)
# Out:
# (114, 1)
#                             verbatim_name
# 0                         Candeina nitida
# 1     Dentoglobigerina altispira _T_ _PL5
# 2    Dentoglobigerina altispira _T_ _PL5_
# 3  Dextral:Sinistral _P. obliquiloculata_
# 4       Dextral:Sinistral _P. praecursor_

# %%
merged_df = taxa_df.merge(all_taxa_df)
print_df(merged_df)
# Out:
# (117, 28)
#                             verbatim_name  \
# 0                         Candeina nitida
# 1     Dentoglobigerina altispira _T_ _PL5
# 2    Dentoglobigerina altispira _T_ _PL5_
# 3  Dextral:Sinistral _P. obliquiloculata_
# 4  Dextral:Sinistral _P. obliquiloculata_
#
#                                    name  \
# 0                       Candeina nitida
# 1   Dentoglobigerina altispira _T_ _PL5
# 2  Dentoglobigerina altispira _T_ _PL5_
# 3            Dextral P. obliquiloculata
# 4          Sinistral P. obliquiloculata
#
#   name to use (if different from "name") Any taxon above genus genus modifier  \
# 0                                    NaN                   NaN            NaN
# 1             Dentoglobigerina altispira                   NaN            NaN
# 2             Dentoglobigerina altispira                   NaN            NaN
# 3                                    NaN                   NaN            NaN
# 4                                    NaN                   NaN            NaN
#
#           genus name subgenera modifier subgenera name species modifier  \
# 0           Candeina                NaN            NaN              NaN
# 1  Dentoglobigerina                 NaN            NaN              NaN
# 2  Dentoglobigerina                 NaN            NaN              NaN
# 3       Pulleniatina                NaN            NaN              NaN
# 4       Pulleniatina                NaN            NaN              NaN
#
#       species name  ... family_taxon_id family_taxon_name order_taxon_id  \
# 0           nitida  ...          422277       Candeinidae            NaN
# 1        altispira  ...           82191    Globigerinidae            NaN
# 2        altispira  ...           82191    Globigerinidae            NaN
# 3  obliquiloculata  ...           82192   Globorotaliidae            NaN
# 4  obliquiloculata  ...           82192   Globorotaliidae            NaN
#
#   order_taxon_name class_taxon_id class_taxon_name phylum_taxon_id  \
# 0              NaN            NaN              NaN          288974
# 1              NaN            NaN              NaN          288974
# 2              NaN            NaN              NaN          288974
# 3              NaN            NaN              NaN          288974
# 4              NaN            NaN              NaN          288974
#
#   phylum_taxon_name kingdom_taxon_id kingdom_taxon_name
# 0      Foraminifera           212476           Rhizaria
# 1      Foraminifera           212476           Rhizaria
# 2      Foraminifera           212476           Rhizaria
# 3      Foraminifera           212476           Rhizaria
# 4      Foraminifera           212476           Rhizaria
#
# [5 rows x 28 columns]

# %%
add_normalized_name_column(merged_df)
add_normalized_name_column(merged_df, include_descriptor=False, 
                           include_modifier=False, col_name='basic_name')

print_df(merged_df)
# Out:
# (117, 30)
#                             verbatim_name  \
# 0                         Candeina nitida
# 1     Dentoglobigerina altispira _T_ _PL5
# 2    Dentoglobigerina altispira _T_ _PL5_
# 3  Dextral:Sinistral _P. obliquiloculata_
# 4  Dextral:Sinistral _P. obliquiloculata_
#
#                                    name  \
# 0                       Candeina nitida
# 1   Dentoglobigerina altispira _T_ _PL5
# 2  Dentoglobigerina altispira _T_ _PL5_
# 3            Dextral P. obliquiloculata
# 4          Sinistral P. obliquiloculata
#
#   name to use (if different from "name") Any taxon above genus genus modifier  \
# 0                                    NaN                   NaN            NaN
# 1             Dentoglobigerina altispira                   NaN            NaN
# 2             Dentoglobigerina altispira                   NaN            NaN
# 3                                    NaN                   NaN            NaN
# 4                                    NaN                   NaN            NaN
#
#           genus name subgenera modifier subgenera name species modifier  \
# 0           Candeina                NaN            NaN              NaN
# 1  Dentoglobigerina                 NaN            NaN              NaN
# 2  Dentoglobigerina                 NaN            NaN              NaN
# 3       Pulleniatina                NaN            NaN              NaN
# 4       Pulleniatina                NaN            NaN              NaN
#
#       species name  ... order_taxon_id order_taxon_name class_taxon_id  \
# 0           nitida  ...            NaN              NaN            NaN
# 1        altispira  ...            NaN              NaN            NaN
# 2        altispira  ...            NaN              NaN            NaN
# 3  obliquiloculata  ...            NaN              NaN            NaN
# 4  obliquiloculata  ...            NaN              NaN            NaN
#
#   class_taxon_name phylum_taxon_id phylum_taxon_name kingdom_taxon_id  \
# 0              NaN          288974      Foraminifera           212476
# 1              NaN          288974      Foraminifera           212476
# 2              NaN          288974      Foraminifera           212476
# 3              NaN          288974      Foraminifera           212476
# 4              NaN          288974      Foraminifera           212476
#
#   kingdom_taxon_name                           normalized_name  \
# 0           Rhizaria                           Candeina nitida
# 1           Rhizaria                Dentoglobigerina altispira
# 2           Rhizaria                Dentoglobigerina altispira
# 3           Rhizaria    Pulleniatina obliquiloculata (dextral)
# 4           Rhizaria  Pulleniatina obliquiloculata (sinistral)
#
#                      basic_name
# 0               Candeina nitida
# 1    Dentoglobigerina altispira
# 2    Dentoglobigerina altispira
# 3  Pulleniatina obliquiloculata
# 4  Pulleniatina obliquiloculata
#
# [5 rows x 30 columns]

# %%
taxa_df = merged_df[['verbatim_name', 'normalized_name', 'basic_name']]
taxa_df
# Out:
#                                 verbatim_name  \
# 0                             Candeina nitida
# 1         Dentoglobigerina altispira _T_ _PL5
# 2        Dentoglobigerina altispira _T_ _PL5_
# 3      Dextral:Sinistral _P. obliquiloculata_
# 4      Dextral:Sinistral _P. obliquiloculata_
# ..                                        ...
# 112  Sphaeroidinella dehiscens sensu lato _B_
# 113              Sphaeroidinellopsis kochi _T
# 114             Sphaeroidinellopsis kochi _T_
# 115   Sphaeroidinellopsis seminulina _T_ _PL4
# 116  Sphaeroidinellopsis seminulina _T_ _PL4_
#
#                               normalized_name                      basic_name
# 0                             Candeina nitida                 Candeina nitida
# 1                  Dentoglobigerina altispira      Dentoglobigerina altispira
# 2                  Dentoglobigerina altispira      Dentoglobigerina altispira
# 3      Pulleniatina obliquiloculata (dextral)    Pulleniatina obliquiloculata
# 4    Pulleniatina obliquiloculata (sinistral)    Pulleniatina obliquiloculata
# ..                                        ...                             ...
# 112            Sphaeroidinella s.l. dehiscens       Sphaeroidinella dehiscens
# 113                 Sphaeroidinellopsis kochi       Sphaeroidinellopsis kochi
# 114                 Sphaeroidinellopsis kochi       Sphaeroidinellopsis kochi
# 115            Sphaeroidinellopsis seminulina  Sphaeroidinellopsis seminulina
# 116            Sphaeroidinellopsis seminulina  Sphaeroidinellopsis seminulina
#
# [117 rows x 3 columns]

# %%
taxa_df.to_csv(noramalized_taxa_path, index=False)
